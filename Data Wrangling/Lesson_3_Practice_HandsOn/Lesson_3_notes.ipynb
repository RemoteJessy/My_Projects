# %%
import pandas as pd

# %%
superheroes = pd.read_csv('superheroes.csv')

# %%
superheroes
# Out:
#      Unnamed: 0            name  Gender Eye color             Race Hair color  \
# 0             6     Adam Monroe    Male      blue                -      Blond
# 1             8        Agent 13  Female      blue                -      Blond
# 2            10      Agent Zero    Male         -                -          -
# 3            11      Air-Walker    Male      blue                -      White
# 4            13      Alan Scott    Male      blue                -      Blond
# ..          ...             ...     ...       ...              ...        ...
# 729          17           Alien    Male         -  Xenomorph XX121    No Hair
# 730         527        Predator    Male         -           Yautja          -
# 731         731            Yoda    Male     brown   Yoda's species      White
# 732         274          Gamora  Female    yellow    Zen-Whoberian      Black
# 733         611  Solomon Grundy    Male     black           Zombie      White
#
# ...

# %%
def gender (series): 
    if series == "Male":
        return 0
    if series == "Female": 
        return 1

# %%
superheroes['GenderR'] = superheroes['Gender'].apply(gender)
